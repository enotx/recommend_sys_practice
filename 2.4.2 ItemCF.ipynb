# %%
# 尝试自行实现基于ItemCF的TopN推荐
# 数据源为movielens的1M老数据

# %%
# 定几个global变量
K = 80 #推荐中最相似的Top用户数
N = 10 #推荐结果中最Top的item数
R = 1 # 正反馈系数
SEED = 10
TRAIN_RATE = 0.8 # 训练集比例

# %%
## 读取数据，数据源为movielens的1M数据
import pandas as pd
rnames = ['user_id', 'item_id', 'rating', 'timestamp']
ratings = pd.read_table('dataset/ml-1m/ratings.dat', sep='::', header=None, names=rnames, engine='python')

## 截取其中的user_id和movie_id列
df = pd.DataFrame(data = ratings, columns = ['user_id','item_id'])


## 按比例拆分train_set和test_set
## 这只是简单拆分，实际按书中描述，应当分组反复训练
import random

train_set = []
test_set = []
for index, row in df.iterrows():
    if random.random()>TRAIN_RATE:
        test_set.append([row['user_id'], row['item_id']])
    else:
        train_set.append([row['user_id'], row['item_id']])
        
train_set = pd.DataFrame(data = train_set, columns = ['user_id','item_id'])
test_set = pd.DataFrame(data = test_set, columns = ['user_id','item_id'])

# %%
user_list = train_set['user_id']
user_list_test = test_set['user_id']
item_list = train_set['item_id']
item_list_test = test_set['item_id']

## 建用户到物品的倒排表user_item
## 同时建立item_user的关系，用于计算模长
user_item = dict()
item_user = dict()


for k in range(item_list.count()):
    u = user_list.iloc[k]
    i = item_list.iloc[k]
    if i not in item_user:
        item_user[i] = set()
    item_user[i].add(u)
    
    if u not in user_item:
        user_item[u] = set()
    user_item[u].add(i)

## 测试集
item_user_test = dict()
user_item_test = dict()
for k in range(user_list_test.count()):
    u = user_list_test.iloc[k]
    i = item_list_test.iloc[k]
    if i not in item_user_test:
        item_user_test[i] = set()
    item_user_test[i].add(u)
    
    if u not in user_item_test:
        user_item_test[u] = set()
    user_item_test[u].add(i)

# %%
## 对用户，建立物品之间的关联关系

import math

C = dict() # 普通的稀疏矩阵

for u, items in user_item.items():
    for i in items:
        C.setdefault(i, dict())
        for j in items:
            if i == j:
                continue
            C[i].setdefault(j,0)
            C[i][j] += 1

## 计算用户相关性

W = C.copy() # 余弦相似度

for i, related_items in C.items():
    for j, c_ij in related_items.items():
        W[i][j] = c_ij/math.sqrt(len(item_user[i])*len(item_user[j]))

# %%
## ItemCF推荐函数
from operator import itemgetter

def recommend(u, W , topN, relatedK):
    rank = dict()
    for i in user_item[u]:
        for j, w_j in sorted(W[i].items(), key = itemgetter(1), reverse = True)[:relatedK]:
            if j in user_item[u]:
                continue
            rank.setdefault(j,0)
            rank[j] += w_j
    r = sorted(rank.items(), key=itemgetter(1), reverse=True)[:topN]
    return set([i[0] for i in r])
#     return (rank)

# %%
## 带解释的ItemCF

from operator import itemgetter

class ItemCFRank(object):
    """docstring for ClassName"""
    def __init__(self):
        super(ItemCFRank, self).__init__()
        self.weight = 0
        self.reason = dict()
        

def recommend_with_explanation(u, W , topN, relatedK):
    rank = dict()
    for i in user_item[u]:
        for j, w_j in sorted(W[i].items(), key = itemgetter(1), reverse = True)[:relatedK]:
            if j in user_item[u]:
                continue
            rank.setdefault(j, ItemCFRank())
            rank[j].weight += w_j
            rank[j].reason.setdefault(i, 0)
            rank[j].reason[i] += w_j
    r = sorted(rank.items(), key=itemgetter(1), reverse=True)[:topN]
#     return set([i[0] for i in r])
    return (rank)

# %%
recommend_with_explanation(737, W, N, K)
# Out:
# {1265: <__main__.ItemCFRank at 0x15b1adf98>,
#  588: <__main__.ItemCFRank at 0x15b1adba8>,
#  3114: <__main__.ItemCFRank at 0x15b1adef0>,
#  2355: <__main__.ItemCFRank at 0x15b1adf28>,
#  356: <__main__.ItemCFRank at 0x15b1adbe0>,
#  34: <__main__.ItemCFRank at 0x15b1adda0>,
#  260: <__main__.ItemCFRank at 0x15b1addd8>,
#  2396: <__main__.ItemCFRank at 0x15b1ade48>,
#  364: <__main__.ItemCFRank at 0x15b1ade10>,
#  1923: <__main__.ItemCFRank at 0x15b1ade80>,
#  595: <__main__.ItemCFRank at 0x15b1adeb8>,
#  1197: <__main__.ItemCFRank at 0x15b1adc50>,
#  608: <__main__.ItemCFRank at 0x15b1adc88>,
#  1517: <__main__.ItemCFRank at 0x15b1adcc0>,
#  1784: <__main__.ItemCFRank at 0x15b1add30>,
#  3253: <__main__.ItemCFRank at 0x15b1add68>,
#  2797: <__main__.ItemCFRank at 0x15b1adcf8>,
#  2174: <__main__.ItemCFRank at 0x15b1adc18>,
#  480: <__main__.ItemCFRank at 0x15b1adb00>,
#  2081: <__main__.ItemCFRank at 0x15b1adb38>,
#  1641: <__main__.ItemCFRank at 0x15b1adb70>,
#  1210: <__main__.ItemCFRank at 0x15b1ad9e8>,
#  39: <__main__.ItemCFRank at 0x15b1ada58>,
#  1240: <__main__.ItemCFRank at 0x15b1ada90>,
#  377: <__main__.ItemCFRank at 0x15b1ada20>,
#  1291: <__main__.ItemCFRank at 0x15b1ad9b0>,
#  1500: <__main__.ItemCFRank at 0x15b1ad780>,
#  1036: <__main__.ItemCFRank at 0x15b1ad7b8>,
#  1394: <__main__.ItemCFRank at 0x15b1ad7f0>,
#  1073: <__main__.ItemCFRank at 0x15b1ad828>,
#  367: <__main__.ItemCFRank at 0x15b1ad860>,
#  3255: <__main__.ItemCFRank at 0x15b0fd668>,
#  1307: <__main__.ItemCFRank at 0x15b0fdb00>,
#  380: <__main__.ItemCFRank at 0x15b0fda20>,
#  780: <__main__.ItemCFRank at 0x15b0fdd68>,
#  1968: <__main__.ItemCFRank at 0x15b0fda90>,
#  587: <__main__.ItemCFRank at 0x15b0fdac8>,
#  2916: <__main__.ItemCFRank at 0x15b0fd748>,
#  110: <__main__.ItemCFRank at 0x15b0fd630>,
#  551: <__main__.ItemCFRank at 0x15b0fd550>,
#  2000: <__main__.ItemCFRank at 0x15b0fd7f0>,
#  1610: <__main__.ItemCFRank at 0x15b0fd518>,
#  357: <__main__.ItemCFRank at 0x15b0fd780>,
#  1282: <__main__.ItemCFRank at 0x15b0fd5f8>,
#  21: <__main__.ItemCFRank at 0x15b0fdd30>,
#  1704: <__main__.ItemCFRank at 0x15b0fd898>,
#  1259: <__main__.ItemCFRank at 0x15b0fd5c0>,
#  3175: <__main__.ItemCFRank at 0x15b1b9128>,
#  590: <__main__.ItemCFRank at 0x15b1b9048>,
#  2080: <__main__.ItemCFRank at 0x15b1b9198>,
#  2078: <__main__.ItemCFRank at 0x15b1b9240>,
#  594: <__main__.ItemCFRank at 0x15b1b9278>,
#  1022: <__main__.ItemCFRank at 0x15b1b92b0>,
#  1029: <__main__.ItemCFRank at 0x15b1b91d0>,
#  1380: <__main__.ItemCFRank at 0x15b1b9208>,
#  1032: <__main__.ItemCFRank at 0x15b1b92e8>,
#  914: <__main__.ItemCFRank at 0x15b1b9438>,
#  1035: <__main__.ItemCFRank at 0x15b1b9320>,
#  2096: <__main__.ItemCFRank at 0x15b1b9358>,
#  2087: <__main__.ItemCFRank at 0x15b1b93c8>,
#  1947: <__main__.ItemCFRank at 0x15b1b9400>,
#  3396: <__main__.ItemCFRank at 0x15b1b9390>,
#  596: <__main__.ItemCFRank at 0x15b1b9470>,
#  3448: <__main__.ItemCFRank at 0x15b1b94a8>,
#  2406: <__main__.ItemCFRank at 0x15b1b9630>,
#  2746: <__main__.ItemCFRank at 0x15b1b9668>,
#  2085: <__main__.ItemCFRank at 0x15b1b94e0>,
#  2100: <__main__.ItemCFRank at 0x15b1b9518>,
#  2470: <__main__.ItemCFRank at 0x15b1b9550>,
#  2018: <__main__.ItemCFRank at 0x15b1b95c0>,
#  2657: <__main__.ItemCFRank at 0x15b1b95f8>,
#  1304: <__main__.ItemCFRank at 0x15b1b9588>,
#  2407: <__main__.ItemCFRank at 0x15b1b96a0>,
#  1088: <__main__.ItemCFRank at 0x15b1b9898>,
#  2054: <__main__.ItemCFRank at 0x15b1b96d8>,
#  1220: <__main__.ItemCFRank at 0x15b1b9828>,
#  899: <__main__.ItemCFRank at 0x15b1b9860>,
#  2640: <__main__.ItemCFRank at 0x15b1b9710>,
#  2137: <__main__.ItemCFRank at 0x15b1b9748>,
#  1294: <__main__.ItemCFRank at 0x15b1b97b8>,
#  2302: <__main__.ItemCFRank at 0x15b1b97f0>,
#  3526: <__main__.ItemCFRank at 0x15b1b9780>,
#  3671: <__main__.ItemCFRank at 0x15b1b98d0>,
#  2565: <__main__.ItemCFRank at 0x15b1b9908>,
#  586: <__main__.ItemCFRank at 0x15b1b9940>,
#  1031: <__main__.ItemCFRank at 0x15b1b99e8>,
#  3397: <__main__.ItemCFRank at 0x15b1b99b0>,
#  3363: <__main__.ItemCFRank at 0x15b1b9a20>,
#  539: <__main__.ItemCFRank at 0x15b1b9a58>,
#  3421: <__main__.ItemCFRank at 0x15b1b9a90>,
#  1080: <__main__.ItemCFRank at 0x15b1b9ac8>,
#  474: <__main__.ItemCFRank at 0x15b1b9b00>,
#  2278: <__main__.ItemCFRank at 0x15b1b9b38>,
#  1370: <__main__.ItemCFRank at 0x15b1b9b70>,
#  733: <__main__.ItemCFRank at 0x15b1b9ba8>,
#  47: <__main__.ItemCFRank at 0x15b1b9be0>,
#  2353: <__main__.ItemCFRank at 0x15b1b9c18>,
#  2058: <__main__.ItemCFRank at 0x15b1b9c50>,
#  3256: <__main__.ItemCFRank at 0x15b1b9c88>,
#  349: <__main__.ItemCFRank at 0x15b1b9cc0>,
#  1573: <__main__.ItemCFRank at 0x15b1b9cf8>,
#  1089: <__main__.ItemCFRank at 0x15b1b9d30>,
#  555: <__main__.ItemCFRank at 0x15b1b9d68>,
#  1912: <__main__.ItemCFRank at 0x15b1b9da0>,
#  16: <__main__.ItemCFRank at 0x15b1b9dd8>,
#  1608: <__main__.ItemCFRank at 0x15b1b9e10>,
#  1729: <__main__.ItemCFRank at 0x15b1b9e48>,
#  163: <__main__.ItemCFRank at 0x15b1b9e80>,
#  3107: <__main__.ItemCFRank at 0x15b1b9eb8>,
#  165: <__main__.ItemCFRank at 0x15b1b9ef0>,
#  353: <__main__.ItemCFRank at 0x15b1b9f28>,
#  1552: <__main__.ItemCFRank at 0x15b1b9f60>,
#  1645: <__main__.ItemCFRank at 0x15b1b9f98>,
#  70: <__main__.ItemCFRank at 0x15b1b9fd0>,
#  1722: <__main__.ItemCFRank at 0x15b1be048>,
#  1377: <__main__.ItemCFRank at 0x15b1be080>,
#  3527: <__main__.ItemCFRank at 0x15b1be0b8>,
#  95: <__main__.ItemCFRank at 0x15b1be0f0>,
#  3020: <__main__.ItemCFRank at 0x15b1be128>,
#  292: <__main__.ItemCFRank at 0x15b1be160>,
#  1047: <__main__.ItemCFRank at 0x15b1be198>,
#  1918: <__main__.ItemCFRank at 0x15b1be1d0>,
#  10: <__main__.ItemCFRank at 0x15b1be208>,
#  1917: <__main__.ItemCFRank at 0x15b1be240>,
#  293: <__main__.ItemCFRank at 0x15b1be278>,
#  1358: <__main__.ItemCFRank at 0x15b1be2b0>,
#  161: <__main__.ItemCFRank at 0x15b1be2e8>,
#  434: <__main__.ItemCFRank at 0x15b1be320>,
#  786: <__main__.ItemCFRank at 0x15b1be358>,
#  2167: <__main__.ItemCFRank at 0x15b1be390>,
#  368: <__main__.ItemCFRank at 0x15b1be3c8>,
#  1676: <__main__.ItemCFRank at 0x15b1be400>,
#  316: <__main__.ItemCFRank at 0x15b1be438>,
#  1391: <__main__.ItemCFRank at 0x15b1be470>,
#  1320: <__main__.ItemCFRank at 0x15b1be4a8>,
#  736: <__main__.ItemCFRank at 0x15b1be4e0>,
#  1690: <__main__.ItemCFRank at 0x15b1be518>,
#  2012: <__main__.ItemCFRank at 0x15b1be550>,
#  173: <__main__.ItemCFRank at 0x15b1be588>,
#  2617: <__main__.ItemCFRank at 0x15b1be5c0>,
#  208: <__main__.ItemCFRank at 0x15b1be5f8>,
#  2094: <__main__.ItemCFRank at 0x15b1be630>,
#  160: <__main__.ItemCFRank at 0x15b1be668>,
#  1779: <__main__.ItemCFRank at 0x15b1be6a0>,
#  2641: <__main__.ItemCFRank at 0x15b1be6d8>,
#  1882: <__main__.ItemCFRank at 0x15b1be710>,
#  1037: <__main__.ItemCFRank at 0x15b1be748>,
#  2985: <__main__.ItemCFRank at 0x15b1be780>,
#  2105: <__main__.ItemCFRank at 0x15b1be7b8>,
#  2006: <__main__.ItemCFRank at 0x15b1be7f0>,
#  1591: <__main__.ItemCFRank at 0x15b1be828>,
#  1200: <__main__.ItemCFRank at 0x15b1be860>,
#  2699: <__main__.ItemCFRank at 0x15b1be898>,
#  1371: <__main__.ItemCFRank at 0x15b1be8d0>,
#  849: <__main__.ItemCFRank at 0x15b1be908>,
#  1127: <__main__.ItemCFRank at 0x15b1be940>,
#  3697: <__main__.ItemCFRank at 0x15b1be978>,
#  185: <__main__.ItemCFRank at 0x15b1be9b0>,
#  442: <__main__.ItemCFRank at 0x15b1be9e8>,
#  2986: <__main__.ItemCFRank at 0x15b1bea20>,
#  2701: <__main__.ItemCFRank at 0x15b1bea58>,
#  788: <__main__.ItemCFRank at 0x15b1bea90>,
#  2959: <__main__.ItemCFRank at 0x15b1beac8>,
#  253: <__main__.ItemCFRank at 0x15b1beb00>,
#  1407: <__main__.ItemCFRank at 0x15b1beb38>,
#  2719: <__main__.ItemCFRank at 0x15b1beb70>,
#  2683: <__main__.ItemCFRank at 0x15b1beba8>,
#  2976: <__main__.ItemCFRank at 0x15b1bebe0>,
#  3174: <__main__.ItemCFRank at 0x15b1bec18>,
#  1339: <__main__.ItemCFRank at 0x15b1bec50>,
#  2712: <__main__.ItemCFRank at 0x15b1bec88>,
#  2706: <__main__.ItemCFRank at 0x15b1becc0>,
#  2395: <__main__.ItemCFRank at 0x15b1becf8>,
#  2841: <__main__.ItemCFRank at 0x15b1bed30>,
#  2428: <__main__.ItemCFRank at 0x15b1bed68>,
#  2995: <__main__.ItemCFRank at 0x15b1beda0>,
#  3005: <__main__.ItemCFRank at 0x15b1bedd8>,
#  3499: <__main__.ItemCFRank at 0x15b1bee10>,
#  1717: <__main__.ItemCFRank at 0x15b1bee48>,
#  2502: <__main__.ItemCFRank at 0x15b1bee80>,
#  2003: <__main__.ItemCFRank at 0x15b1beeb8>,
#  3113: <__main__.ItemCFRank at 0x15b1beef0>,
#  724: <__main__.ItemCFRank at 0x15b1bef28>,
#  3273: <__main__.ItemCFRank at 0x15b1bef60>,
#  2580: <__main__.ItemCFRank at 0x15b1bef98>,
#  2770: <__main__.ItemCFRank at 0x15b1befd0>,
#  2605: <__main__.ItemCFRank at 0x15b1c6048>,
#  2599: <__main__.ItemCFRank at 0x15b1c6080>,
#  2840: <__main__.ItemCFRank at 0x15b1c60b8>,
#  785: <__main__.ItemCFRank at 0x15b1c60f0>,
#  1644: <__main__.ItemCFRank at 0x15b1c6128>,
#  1258: <__main__.ItemCFRank at 0x15b1c6160>,
#  3052: <__main__.ItemCFRank at 0x15b1c6198>,
#  2723: <__main__.ItemCFRank at 0x15b1c61d0>,
#  2826: <__main__.ItemCFRank at 0x15b1c6208>,
#  1994: <__main__.ItemCFRank at 0x15b1c6240>,
#  2713: <__main__.ItemCFRank at 0x15b1c6278>,
#  1214: <__main__.ItemCFRank at 0x15b1c62b0>,
#  1653: <__main__.ItemCFRank at 0x15b1c62e8>,
#  1396: <__main__.ItemCFRank at 0x15b1c6320>,
#  3471: <__main__.ItemCFRank at 0x15b1c6358>,
#  2529: <__main__.ItemCFRank at 0x15b1c6390>,
#  1094: <__main__.ItemCFRank at 0x15b1c63c8>,
#  1193: <__main__.ItemCFRank at 0x15b1c6400>,
#  1393: <__main__.ItemCFRank at 0x15b1c6438>,
#  150: <__main__.ItemCFRank at 0x15b1c6470>,
#  1090: <__main__.ItemCFRank at 0x15b1c64a8>,
#  2890: <__main__.ItemCFRank at 0x15b1c64e0>,
#  2324: <__main__.ItemCFRank at 0x15b1c6518>,
#  36: <__main__.ItemCFRank at 0x15b1c6550>,
#  1222: <__main__.ItemCFRank at 0x15b1c6588>,
#  1682: <__main__.ItemCFRank at 0x15b1c65c0>,
#  1266: <__main__.ItemCFRank at 0x15b1c65f8>,
#  1961: <__main__.ItemCFRank at 0x15b1c6630>,
#  1250: <__main__.ItemCFRank at 0x15b1c6668>,
#  2940: <__main__.ItemCFRank at 0x15b1c66a0>,
#  1069: <__main__.ItemCFRank at 0x15b1c66d8>,
#  2726: <__main__.ItemCFRank at 0x15b1c6710>,
#  2182: <__main__.ItemCFRank at 0x15b1c6748>,
#  922: <__main__.ItemCFRank at 0x15b1c6780>,
#  1260: <__main__.ItemCFRank at 0x15b1c67b8>,
#  1152: <__main__.ItemCFRank at 0x15b1c67f0>,
#  2727: <__main__.ItemCFRank at 0x15b1c6828>,
#  1068: <__main__.ItemCFRank at 0x15b1c6860>,
#  3334: <__main__.ItemCFRank at 0x15b1c6898>,
#  2935: <__main__.ItemCFRank at 0x15b1c68d0>,
#  1344: <__main__.ItemCFRank at 0x15b1c6908>,
#  2206: <__main__.ItemCFRank at 0x15b1c6940>,
#  946: <__main__.ItemCFRank at 0x15b1c6978>,
#  2208: <__main__.ItemCFRank at 0x15b1c69b0>,
#  1267: <__main__.ItemCFRank at 0x15b1c69e8>,
#  2936: <__main__.ItemCFRank at 0x15b1c6a20>,
#  3134: <__main__.ItemCFRank at 0x15b1c6a58>,
#  1212: <__main__.ItemCFRank at 0x15b1c6a90>,
#  1940: <__main__.ItemCFRank at 0x15b1c6ac8>,
#  929: <__main__.ItemCFRank at 0x15b1c6b00>,
#  2187: <__main__.ItemCFRank at 0x15b1c6b38>,
#  3093: <__main__.ItemCFRank at 0x15b1c6b70>,
#  746: <__main__.ItemCFRank at 0x15b1c6ba8>,
#  928: <__main__.ItemCFRank at 0x15b1c6be0>,
#  3736: <__main__.ItemCFRank at 0x15b1c6c18>,
#  2511: <__main__.ItemCFRank at 0x15b1c6c50>,
#  936: <__main__.ItemCFRank at 0x15b1c6c88>,
#  3307: <__main__.ItemCFRank at 0x15b1c6cc0>,
#  2130: <__main__.ItemCFRank at 0x15b1c6cf8>,
#  3629: <__main__.ItemCFRank at 0x15b1c6d30>,
#  1281: <__main__.ItemCFRank at 0x15b1c6d68>,
#  1178: <__main__.ItemCFRank at 0x15b1c6da0>,
#  916: <__main__.ItemCFRank at 0x15b1c6dd8>,
#  1237: <__main__.ItemCFRank at 0x15b1c6e10>,
#  3075: <__main__.ItemCFRank at 0x15b1c6e48>,
#  3022: <__main__.ItemCFRank at 0x15b1c6e80>,
#  1944: <__main__.ItemCFRank at 0x15b1c6eb8>,
#  951: <__main__.ItemCFRank at 0x15b1c6ef0>,
#  898: <__main__.ItemCFRank at 0x15b1c6f28>,
#  906: <__main__.ItemCFRank at 0x15b1c6f60>,
#  2183: <__main__.ItemCFRank at 0x15b1c6f98>,
#  1783: <__main__.ItemCFRank at 0x15b1c6fd0>,
#  905: <__main__.ItemCFRank at 0x15b1cf048>,
#  1154: <__main__.ItemCFRank at 0x15b1cf080>,
#  3642: <__main__.ItemCFRank at 0x15b1cf0b8>,
#  3379: <__main__.ItemCFRank at 0x15b1cf0f0>,
#  982: <__main__.ItemCFRank at 0x15b1cf128>,
#  2920: <__main__.ItemCFRank at 0x15b1cf160>,
#  3792: <__main__.ItemCFRank at 0x15b1cf198>,
#  945: <__main__.ItemCFRank at 0x15b1cf1d0>,
#  2202: <__main__.ItemCFRank at 0x15b1cf208>,
#  2351: <__main__.ItemCFRank at 0x15b1cf240>,
#  3475: <__main__.ItemCFRank at 0x15b1cf278>,
#  2184: <__main__.ItemCFRank at 0x15b1cf2b0>,
#  2485: <__main__.ItemCFRank at 0x15b1cf2e8>,
#  2572: <__main__.ItemCFRank at 0x15b1cf320>,
#  1513: <__main__.ItemCFRank at 0x15b1cf358>,
#  2694: <__main__.ItemCFRank at 0x15b1cf390>,
#  1911: <__main__.ItemCFRank at 0x15b1cf3c8>,
#  1777: <__main__.ItemCFRank at 0x15b1cf400>,
#  2541: <__main__.ItemCFRank at 0x15b1cf438>,
#  2718: <__main__.ItemCFRank at 0x15b1cf470>,
#  2805: <__main__.ItemCFRank at 0x15b1cf4a8>,
#  2598: <__main__.ItemCFRank at 0x15b1cf4e0>,
#  2671: <__main__.ItemCFRank at 0x15b1cf518>,
#  339: <__main__.ItemCFRank at 0x15b1cf550>,
#  2558: <__main__.ItemCFRank at 0x15b1cf588>,
#  2881: <__main__.ItemCFRank at 0x15b1cf5c0>,
#  597: <__main__.ItemCFRank at 0x15b1cf5f8>,
#  2496: <__main__.ItemCFRank at 0x15b1cf630>,
#  1569: <__main__.ItemCFRank at 0x15b1cf668>,
#  708: <__main__.ItemCFRank at 0x15b1cf6a0>,
#  1888: <__main__.ItemCFRank at 0x15b1cf6d8>,
#  543: <__main__.ItemCFRank at 0x15b1cf710>,
#  1485: <__main__.ItemCFRank at 0x15b1cf748>,
#  2688: <__main__.ItemCFRank at 0x15b1cf780>,
#  500: <__main__.ItemCFRank at 0x15b1cf7b8>,
#  2125: <__main__.ItemCFRank at 0x15b1cf7f0>,
#  1042: <__main__.ItemCFRank at 0x15b1cf828>,
#  2369: <__main__.ItemCFRank at 0x15b1cf860>,
#  2861: <__main__.ItemCFRank at 0x15b1cf898>,
#  2906: <__main__.ItemCFRank at 0x15b1cf8d0>,
#  440: <__main__.ItemCFRank at 0x15b1cf908>,
#  2806: <__main__.ItemCFRank at 0x15b1cf940>,
#  236: <__main__.ItemCFRank at 0x15b1cf978>,
#  7: <__main__.ItemCFRank at 0x15b1cf9b0>,
#  852: <__main__.ItemCFRank at 0x15b1cf9e8>,
#  800: <__main__.ItemCFRank at 0x15b1cfa20>,
#  1892: <__main__.ItemCFRank at 0x15b1cfa58>,
#  1711: <__main__.ItemCFRank at 0x15b1cfa90>,
#  2474: <__main__.ItemCFRank at 0x15b1e1198>,
#  2915: <__main__.ItemCFRank at 0x15b1e11d0>,
#  3361: <__main__.ItemCFRank at 0x15b1e1208>,
#  1954: <__main__.ItemCFRank at 0x15b1e1240>,
#  2352: <__main__.ItemCFRank at 0x15b1e1278>,
#  1958: <__main__.ItemCFRank at 0x15b1e12b0>,
#  2313: <__main__.ItemCFRank at 0x15b1e12e8>,
#  3591: <__main__.ItemCFRank at 0x15b1e1320>,
#  2245: <__main__.ItemCFRank at 0x15b1e1358>,
#  2312: <__main__.ItemCFRank at 0x15b1e1390>,
#  1957: <__main__.ItemCFRank at 0x15b1e13c8>,
#  2240: <__main__.ItemCFRank at 0x15b1e1400>,
#  3039: <__main__.ItemCFRank at 0x15b1e1438>,
#  1663: <__main__.ItemCFRank at 0x15b1e1470>,
#  3552: <__main__.ItemCFRank at 0x15b1e14a8>,
#  3169: <__main__.ItemCFRank at 0x15b1e14e0>,
#  1293: <__main__.ItemCFRank at 0x15b1e1518>,
#  1955: <__main__.ItemCFRank at 0x15b1e1550>,
#  3072: <__main__.ItemCFRank at 0x15b1e1588>,
#  2146: <__main__.ItemCFRank at 0x15b1e15c0>,
#  2114: <__main__.ItemCFRank at 0x15b1e15f8>,
#  3210: <__main__.ItemCFRank at 0x15b1e1630>,
#  2371: <__main__.ItemCFRank at 0x15b1e1668>,
#  1960: <__main__.ItemCFRank at 0x15b1e16a0>,
#  3111: <__main__.ItemCFRank at 0x15b1e16d8>,
#  3040: <__main__.ItemCFRank at 0x15b1e1710>,
#  3699: <__main__.ItemCFRank at 0x15b1e1748>,
#  2739: <__main__.ItemCFRank at 0x15b1e1780>,
#  2795: <__main__.ItemCFRank at 0x15b1e17b8>,
#  2942: <__main__.ItemCFRank at 0x15b1e17f0>,
#  2616: <__main__.ItemCFRank at 0x15b1e1828>,
#  485: <__main__.ItemCFRank at 0x15b1e1860>,
#  1499: <__main__.ItemCFRank at 0x15b1e1898>,
#  2002: <__main__.ItemCFRank at 0x15b1e18d0>,
#  3489: <__main__.ItemCFRank at 0x15b1e1908>,
#  1556: <__main__.ItemCFRank at 0x15b1e1940>,
#  2642: <__main__.ItemCFRank at 0x15b1e1978>,
#  44: <__main__.ItemCFRank at 0x15b1e19b0>,
#  1100: <__main__.ItemCFRank at 0x15b1e19e8>,
#  1438: <__main__.ItemCFRank at 0x15b1e1a20>,
#  1479: <__main__.ItemCFRank at 0x15b1e1a58>,
#  2115: <__main__.ItemCFRank at 0x15b1e1a90>,
#  466: <__main__.ItemCFRank at 0x15b1e1ac8>,
#  2001: <__main__.ItemCFRank at 0x15b1e1b00>,
#  546: <__main__.ItemCFRank at 0x15b1e1b38>,
#  552: <__main__.ItemCFRank at 0x15b1e1b70>,
#  3705: <__main__.ItemCFRank at 0x15b1e1ba8>,
#  2405: <__main__.ItemCFRank at 0x15b1e1be0>,
#  2717: <__main__.ItemCFRank at 0x15b1e1c18>,
#  2126: <__main__.ItemCFRank at 0x15b1e1c50>,
#  2421: <__main__.ItemCFRank at 0x15b1e1c88>,
#  3504: <__main__.ItemCFRank at 0x15b1ad4a8>,
#  1965: <__main__.ItemCFRank at 0x15b1e97b8>,
#  2065: <__main__.ItemCFRank at 0x15b1e9828>,
#  2528: <__main__.ItemCFRank at 0x15b1e9860>,
#  1253: <__main__.ItemCFRank at 0x15b1e9898>,
#  910: <__main__.ItemCFRank at 0x15b1e98d0>,
#  1256: <__main__.ItemCFRank at 0x15b1e9908>,
#  3362: <__main__.ItemCFRank at 0x15b1e9940>,
#  921: <__main__.ItemCFRank at 0x15b1e9978>,
#  674: <__main__.ItemCFRank at 0x15b1e99b0>,
#  1288: <__main__.ItemCFRank at 0x15b1e99e8>,
#  2664: <__main__.ItemCFRank at 0x15b1e9a20>,
#  2788: <__main__.ItemCFRank at 0x15b1e9a58>,
#  3812: <__main__.ItemCFRank at 0x15b1e9a90>,
#  2144: <__main__.ItemCFRank at 0x15b1e9ac8>,
#  2150: <__main__.ItemCFRank at 0x15b1e9b00>,
#  2248: <__main__.ItemCFRank at 0x15b1e9b38>,
#  2804: <__main__.ItemCFRank at 0x15b1e9b70>,
#  2064: <__main__.ItemCFRank at 0x15b1e9ba8>,
#  3608: <__main__.ItemCFRank at 0x15b1e9be0>,
#  2463: <__main__.ItemCFRank at 0x15b1e9c18>,
#  3152: <__main__.ItemCFRank at 0x15b1e9c50>,
#  1945: <__main__.ItemCFRank at 0x15b1e9c88>,
#  1204: <__main__.ItemCFRank at 0x15b1e9cc0>,
#  3168: <__main__.ItemCFRank at 0x15b1e9cf8>,
#  3201: <__main__.ItemCFRank at 0x15b1e9d30>,
#  3735: <__main__.ItemCFRank at 0x15b1e9d68>,
#  2132: <__main__.ItemCFRank at 0x15b1e9da0>,
#  1272: <__main__.ItemCFRank at 0x15b1e9dd8>,
#  3685: <__main__.ItemCFRank at 0x15b1e9e10>,
#  2067: <__main__.ItemCFRank at 0x15b1e9e48>,
#  1104: <__main__.ItemCFRank at 0x15b1e9e80>,
#  920: <__main__.ItemCFRank at 0x15b1e9eb8>,
#  971: <__main__.ItemCFRank at 0x15b1e9ef0>,
#  1299: <__main__.ItemCFRank at 0x15b1e9f28>,
#  926: <__main__.ItemCFRank at 0x15b1e9f60>,
#  1333: <__main__.ItemCFRank at 0x15b1e9f98>,
#  969: <__main__.ItemCFRank at 0x15b1e9fd0>,
#  3359: <__main__.ItemCFRank at 0x15b1f6048>,
#  3037: <__main__.ItemCFRank at 0x15b1f6080>,
#  909: <__main__.ItemCFRank at 0x15b1f60b8>,
#  2728: <__main__.ItemCFRank at 0x15b1f60f0>,
#  3198: <__main__.ItemCFRank at 0x15b1f6128>,
#  3095: <__main__.ItemCFRank at 0x15b1f6160>,
#  1792: <__main__.ItemCFRank at 0x15b1f6198>,
#  1616: <__main__.ItemCFRank at 0x15b1f61d0>,
#  1687: <__main__.ItemCFRank at 0x15b1f6208>,
#  494: <__main__.ItemCFRank at 0x15b1f6240>,
#  3257: <__main__.ItemCFRank at 0x15b1f6278>,
#  2334: <__main__.ItemCFRank at 0x15b1f62b0>,
#  376: <__main__.ItemCFRank at 0x15b1f62e8>,
#  2654: <__main__.ItemCFRank at 0x15b201a20>,
#  3529: <__main__.ItemCFRank at 0x15b201a58>,
#  2459: <__main__.ItemCFRank at 0x15b201a90>,
#  2753: <__main__.ItemCFRank at 0x15b201ac8>,
#  2983: <__main__.ItemCFRank at 0x15b201b00>,
#  3494: <__main__.ItemCFRank at 0x15b201b38>,
#  2349: <__main__.ItemCFRank at 0x15b201b70>,
#  2550: <__main__.ItemCFRank at 0x15b201ba8>,
#  2346: <__main__.ItemCFRank at 0x15b201be0>,
#  230: <__main__.ItemCFRank at 0x15b201c18>,
#  2519: <__main__.ItemCFRank at 0x15b201c50>,
#  2939: <__main__.ItemCFRank at 0x15b201c88>,
#  2764: <__main__.ItemCFRank at 0x15b201cc0>,
#  3445: <__main__.ItemCFRank at 0x15b201cf8>,
#  2160: <__main__.ItemCFRank at 0x15b201d30>,
#  2247: <__main__.ItemCFRank at 0x15b201d68>,
#  3230: <__main__.ItemCFRank at 0x15b201da0>,
#  2553: <__main__.ItemCFRank at 0x15b201dd8>,
#  3600: <__main__.ItemCFRank at 0x15b201e10>,
#  1268: <__main__.ItemCFRank at 0x15b201e48>,
#  1254: <__main__.ItemCFRank at 0x15b201e80>,
#  3365: <__main__.ItemCFRank at 0x15b201eb8>,
#  955: <__main__.ItemCFRank at 0x15b201ef0>,
#  1405: <__main__.ItemCFRank at 0x15b201f28>,
#  2294: <__main__.ItemCFRank at 0x15b201f60>,
#  2139: <__main__.ItemCFRank at 0x15b201f98>,
#  1025: <__main__.ItemCFRank at 0x15b201fd0>,
#  2089: <__main__.ItemCFRank at 0x15b20d048>,
#  1064: <__main__.ItemCFRank at 0x15b20d080>,
#  1907: <__main__.ItemCFRank at 0x15b20d0b8>,
#  3034: <__main__.ItemCFRank at 0x15b20d0f0>,
#  1205: <__main__.ItemCFRank at 0x15b20d128>,
#  2643: <__main__.ItemCFRank at 0x15b20d160>,
#  2090: <__main__.ItemCFRank at 0x15b20d198>,
#  3439: <__main__.ItemCFRank at 0x15b20d1d0>,
#  2761: <__main__.ItemCFRank at 0x15b20d208>,
#  2048: <__main__.ItemCFRank at 0x15b20d240>,
#  1033: <__main__.ItemCFRank at 0x15b20d278>,
#  3398: <__main__.ItemCFRank at 0x15b20d2b0>,
#  1688: <__main__.ItemCFRank at 0x15b20d2e8>,
#  2687: <__main__.ItemCFRank at 0x15b20d320>,
#  2046: <__main__.ItemCFRank at 0x15b20d358>,
#  1920: <__main__.ItemCFRank at 0x15b20d390>,
#  671: <__main__.ItemCFRank at 0x15b20d3c8>,
#  3054: <__main__.ItemCFRank at 0x15b20d400>,
#  2141: <__main__.ItemCFRank at 0x15b20d438>,
#  1566: <__main__.ItemCFRank at 0x15b20d470>,
#  24: <__main__.ItemCFRank at 0x15b20d4a8>,
#  2722: <__main__.ItemCFRank at 0x15b20d4e0>,
#  2560: <__main__.ItemCFRank at 0x15b20d518>,
#  2772: <__main__.ItemCFRank at 0x15b20d550>,
#  3219: <__main__.ItemCFRank at 0x15b20d588>,
#  2188: <__main__.ItemCFRank at 0x15b20d5c0>,
#  2672: <__main__.ItemCFRank at 0x15b20d5f8>,
#  3203: <__main__.ItemCFRank at 0x15b20d630>,
#  3104: <__main__.ItemCFRank at 0x15b20d668>,
#  1201: <__main__.ItemCFRank at 0x15b20d6a0>,
#  3763: <__main__.ItemCFRank at 0x15b20d6d8>,
#  2949: <__main__.ItemCFRank at 0x15b20d710>,
#  2944: <__main__.ItemCFRank at 0x15b20d748>,
#  3741: <__main__.ItemCFRank at 0x15b20d780>,
#  3788: <__main__.ItemCFRank at 0x15b20d7b8>,
#  1964: <__main__.ItemCFRank at 0x15b20d7f0>,
#  3724: <__main__.ItemCFRank at 0x15b20d828>,
#  783: <__main__.ItemCFRank at 0x15b20d860>,
#  48: <__main__.ItemCFRank at 0x15b20d898>,
#  2092: <__main__.ItemCFRank at 0x15b20d8d0>,
#  1967: <__main__.ItemCFRank at 0x15b20d908>,
#  2161: <__main__.ItemCFRank at 0x15b20d940>,
#  1030: <__main__.ItemCFRank at 0x15b20d978>,
#  2005: <__main__.ItemCFRank at 0x15b20d9b0>,
#  616: <__main__.ItemCFRank at 0x15b20d9e8>,
#  2394: <__main__.ItemCFRank at 0x15b20da20>,
#  3016: <__main__.ItemCFRank at 0x15b20da58>,
#  2953: <__main__.ItemCFRank at 0x15b20da90>,
#  520: <__main__.ItemCFRank at 0x15b20dac8>,
#  2471: <__main__.ItemCFRank at 0x15b20db00>,
#  344: <__main__.ItemCFRank at 0x15b20db38>,
#  3247: <__main__.ItemCFRank at 0x15b20db70>,
#  2124: <__main__.ItemCFRank at 0x15b20dba8>,
#  410: <__main__.ItemCFRank at 0x15b20dbe0>,
#  231: <__main__.ItemCFRank at 0x15b20dc18>,
#  947: <__main__.ItemCFRank at 0x15b1f6b00>,
#  3097: <__main__.ItemCFRank at 0x15b20dc50>,
#  2927: <__main__.ItemCFRank at 0x15b20dc88>,
#  1939: <__main__.ItemCFRank at 0x15b20dcc0>,
#  918: <__main__.ItemCFRank at 0x15b20dcf8>,
#  2731: <__main__.ItemCFRank at 0x15b20dd30>,
#  707: <__main__.ItemCFRank at 0x15b20dd68>,
#  1051: <__main__.ItemCFRank at 0x15b20dda0>,
#  1114: <__main__.ItemCFRank at 0x15b20ddd8>,
#  175: <__main__.ItemCFRank at 0x15b20de10>,
#  1447: <__main__.ItemCFRank at 0x15b20de48>,
#  3423: <__main__.ItemCFRank at 0x15b20de80>,
#  229: <__main__.ItemCFRank at 0x15b20deb8>,
#  42: <__main__.ItemCFRank at 0x15b20def0>,
#  1401: <__main__.ItemCFRank at 0x15b20df28>,
#  482: <__main__.ItemCFRank at 0x15b20df60>,
#  233: <__main__.ItemCFRank at 0x15b20df98>,
#  100: <__main__.ItemCFRank at 0x15b20dfd0>,
#  2410: <__main__.ItemCFRank at 0x15b215048>,
#  22: <__main__.ItemCFRank at 0x15b215080>,
#  372: <__main__.ItemCFRank at 0x15b2150b8>,
#  78: <__main__.ItemCFRank at 0x15b2150f0>,
#  428: <__main__.ItemCFRank at 0x15b215128>,
#  1027: <__main__.ItemCFRank at 0x15b215160>,
#  3425: <__main__.ItemCFRank at 0x15b215198>,
#  2862: <__main__.ItemCFRank at 0x15b2151d0>,
#  999: <__main__.ItemCFRank at 0x15b215208>,
#  18: <__main__.ItemCFRank at 0x15b215240>,
#  2231: <__main__.ItemCFRank at 0x15b215278>,
#  2269: <__main__.ItemCFRank at 0x15b2152b0>,
#  490: <__main__.ItemCFRank at 0x15b2152e8>,
#  2505: <__main__.ItemCFRank at 0x15b215320>,
#  1804: <__main__.ItemCFRank at 0x15b215358>,
#  3478: <__main__.ItemCFRank at 0x15b215390>,
#  259: <__main__.ItemCFRank at 0x15b2153c8>,
#  1054: <__main__.ItemCFRank at 0x15b215400>,
#  3254: <__main__.ItemCFRank at 0x15b215438>,
#  1061: <__main__.ItemCFRank at 0x15b215470>,
#  1601: <__main__.ItemCFRank at 0x15b2154a8>,
#  2561: <__main__.ItemCFRank at 0x15b2154e0>,
#  1190: <__main__.ItemCFRank at 0x15b215518>,
#  209: <__main__.ItemCFRank at 0x15b215550>,
#  805: <__main__.ItemCFRank at 0x15b215588>,
#  1694: <__main__.ItemCFRank at 0x15b2155c0>,
#  3127: <__main__.ItemCFRank at 0x15b2155f8>,
#  2828: <__main__.ItemCFRank at 0x15b1b9080>,
#  1359: <__main__.ItemCFRank at 0x15b215630>,
#  3157: <__main__.ItemCFRank at 0x15b215668>,
#  2568: <__main__.ItemCFRank at 0x15b2156a0>,
#  653: <__main__.ItemCFRank at 0x15b2156d8>,
#  2153: <__main__.ItemCFRank at 0x15b215710>,
#  317: <__main__.ItemCFRank at 0x15b215748>,
#  1702: <__main__.ItemCFRank at 0x15b215780>,
#  3438: <__main__.ItemCFRank at 0x15b2157b8>,
#  158: <__main__.ItemCFRank at 0x15b2157f0>,
#  2142: <__main__.ItemCFRank at 0x15b215828>,
#  355: <__main__.ItemCFRank at 0x15b215860>,
#  2253: <__main__.ItemCFRank at 0x15b215898>,
#  784: <__main__.ItemCFRank at 0x15b2158d0>,
#  2082: <__main__.ItemCFRank at 0x15b215908>,
#  374: <__main__.ItemCFRank at 0x15b215940>,
#  3263: <__main__.ItemCFRank at 0x15b215978>,
#  2004: <__main__.ItemCFRank at 0x15b2159b0>,
#  3300: <__main__.ItemCFRank at 0x15b2159e8>,
#  3593: <__main__.ItemCFRank at 0x15b215a20>,
#  3826: <__main__.ItemCFRank at 0x15b215a58>,
#  3785: <__main__.ItemCFRank at 0x15b215a90>,
#  3615: <__main__.ItemCFRank at 0x15b215ac8>,
#  3827: <__main__.ItemCFRank at 0x15b215b00>,
#  3744: <__main__.ItemCFRank at 0x15b215b38>,
#  2961: <__main__.ItemCFRank at 0x15b215b70>,
#  195: <__main__.ItemCFRank at 0x15b215ba8>,
#  1835: <__main__.ItemCFRank at 0x15b215be0>,
#  1541: <__main__.ItemCFRank at 0x15b215c18>,
#  2316: <__main__.ItemCFRank at 0x15b215c50>,
#  1409: <__main__.ItemCFRank at 0x15b215c88>,
#  289: <__main__.ItemCFRank at 0x15b215cc0>,
#  1593: <__main__.ItemCFRank at 0x15b215cf8>,
#  2497: <__main__.ItemCFRank at 0x15b215d30>,
#  2340: <__main__.ItemCFRank at 0x15b215d68>,
#  3004: <__main__.ItemCFRank at 0x15b215da0>,
#  1894: <__main__.ItemCFRank at 0x15b215dd8>,
#  468: <__main__.ItemCFRank at 0x15b215e10>,
#  3948: <__main__.ItemCFRank at 0x15b215e48>,
#  1148: <__main__.ItemCFRank at 0x15b215e80>,
#  333: <__main__.ItemCFRank at 0x15b215eb8>,
#  104: <__main__.ItemCFRank at 0x15b215ef0>,
#  216: <__main__.ItemCFRank at 0x15b215f28>,
#  69: <__main__.ItemCFRank at 0x15b215f60>,
#  1476: <__main__.ItemCFRank at 0x15b215f98>,
#  3243: <__main__.ItemCFRank at 0x15b215fd0>,
#  663: <__main__.ItemCFRank at 0x15b220048>,
#  2249: <__main__.ItemCFRank at 0x15b220080>,
#  88: <__main__.ItemCFRank at 0x15b2200b8>,
#  413: <__main__.ItemCFRank at 0x15b2200f0>,
#  1257: <__main__.ItemCFRank at 0x15b220128>,
#  3087: <__main__.ItemCFRank at 0x15b220160>,
#  585: <__main__.ItemCFRank at 0x15b220198>,
#  2539: <__main__.ItemCFRank at 0x15b2201d0>,
#  1297: <__main__.ItemCFRank at 0x15b220208>,
#  2794: <__main__.ItemCFRank at 0x15b220240>,
#  3809: <__main__.ItemCFRank at 0x15b220278>,
#  2423: <__main__.ItemCFRank at 0x15b2202b0>,
#  2060: <__main__.ItemCFRank at 0x15b2202e8>,
#  1895: <__main__.ItemCFRank at 0x15b220320>,
#  3261: <__main__.ItemCFRank at 0x15b220358>,
#  2542: <__main__.ItemCFRank at 0x15b220390>,
#  2335: <__main__.ItemCFRank at 0x15b2203c8>,
#  1997: <__main__.ItemCFRank at 0x15b220400>,
#  1262: <__main__.ItemCFRank at 0x15b220438>,
#  1261: <__main__.ItemCFRank at 0x15b220470>,
#  196: <__main__.ItemCFRank at 0x15b2204a8>,
#  1345: <__main__.ItemCFRank at 0x15b2204e0>,
#  1350: <__main__.ItemCFRank at 0x15b220518>,
#  1982: <__main__.ItemCFRank at 0x15b220550>,
#  2366: <__main__.ItemCFRank at 0x15b220588>,
#  2023: <__main__.ItemCFRank at 0x15b2205c0>,
#  1614: <__main__.ItemCFRank at 0x15b2205f8>,
#  2567: <__main__.ItemCFRank at 0x15b220630>,
#  514: <__main__.ItemCFRank at 0x15b220668>,
#  2690: <__main__.ItemCFRank at 0x15b2206a0>,
#  745: <__main__.ItemCFRank at 0x15b2206d8>,
#  3429: <__main__.ItemCFRank at 0x15b220710>,
#  720: <__main__.ItemCFRank at 0x15b220748>,
#  748: <__main__.ItemCFRank at 0x15b220780>,
#  1603: <__main__.ItemCFRank at 0x15b2207b8>,
#  172: <__main__.ItemCFRank at 0x15b2207f0>,
#  911: <__main__.ItemCFRank at 0x15b220828>,
#  3467: <__main__.ItemCFRank at 0x15b220860>,
#  3834: <__main__.ItemCFRank at 0x15b220898>,
#  3872: <__main__.ItemCFRank at 0x15b2208d0>,
#  3871: <__main__.ItemCFRank at 0x15b220908>,
#  3654: <__main__.ItemCFRank at 0x15b220940>,
#  3789: <__main__.ItemCFRank at 0x15b220978>,
#  3811: <__main__.ItemCFRank at 0x15b2209b0>,
#  3038: <__main__.ItemCFRank at 0x15b2209e8>,
#  3634: <__main__.ItemCFRank at 0x15b220a20>,
#  3737: <__main__.ItemCFRank at 0x15b220a58>,
#  3469: <__main__.ItemCFRank at 0x15b220a90>,
#  897: <__main__.ItemCFRank at 0x15b220ac8>,
#  1408: <__main__.ItemCFRank at 0x15b220b00>,
#  1271: <__main__.ItemCFRank at 0x15b220b38>,
#  1172: <__main__.ItemCFRank at 0x15b220b70>,
#  41: <__main__.ItemCFRank at 0x15b220ba8>,
#  176: <__main__.ItemCFRank at 0x15b220be0>,
#  2019: <__main__.ItemCFRank at 0x15b220c18>,
#  3089: <__main__.ItemCFRank at 0x15b220c50>,
#  2732: <__main__.ItemCFRank at 0x15b220c88>,
#  3742: <__main__.ItemCFRank at 0x15b220cc0>,
#  154: <__main__.ItemCFRank at 0x15b220cf8>,
#  3067: <__main__.ItemCFRank at 0x15b220d30>,
#  978: <__main__.ItemCFRank at 0x15b220d68>,
#  2847: <__main__.ItemCFRank at 0x15b220da0>,
#  2897: <__main__.ItemCFRank at 0x15b220dd8>,
#  2068: <__main__.ItemCFRank at 0x15b220e10>,
#  668: <__main__.ItemCFRank at 0x15b220e48>,
#  3224: <__main__.ItemCFRank at 0x15b220e80>,
#  2729: <__main__.ItemCFRank at 0x15b220eb8>,
#  2143: <__main__.ItemCFRank at 0x15b220ef0>,
#  2792: <__main__.ItemCFRank at 0x15b220f28>,
#  3868: <__main__.ItemCFRank at 0x15b220f60>,
#  1233: <__main__.ItemCFRank at 0x15b220f98>,
#  1211: <__main__.ItemCFRank at 0x15b220fd0>,
#  1150: <__main__.ItemCFRank at 0x15b230048>,
#  2075: <__main__.ItemCFRank at 0x15b230080>,
#  3091: <__main__.ItemCFRank at 0x15b2300b8>,
#  2970: <__main__.ItemCFRank at 0x15b2300f0>,
#  1131: <__main__.ItemCFRank at 0x15b230128>,
#  3545: <__main__.ItemCFRank at 0x15b230160>,
#  1273: <__main__.ItemCFRank at 0x15b230198>,
#  1238: <__main__.ItemCFRank at 0x15b2301d0>,
#  3341: <__main__.ItemCFRank at 0x15b230208>,
#  2926: <__main__.ItemCFRank at 0x15b230240>,
#  2971: <__main__.ItemCFRank at 0x15b230278>,
#  3700: <__main__.ItemCFRank at 0x15b2302b0>,
#  2859: <__main__.ItemCFRank at 0x15b2302e8>,
#  1289: <__main__.ItemCFRank at 0x15b230320>,
#  2239: <__main__.ItemCFRank at 0x15b230358>,
#  1171: <__main__.ItemCFRank at 0x15b230390>,
#  3088: <__main__.ItemCFRank at 0x15b2303c8>,
#  3061: <__main__.ItemCFRank at 0x15b230400>,
#  900: <__main__.ItemCFRank at 0x15b230438>,
#  2863: <__main__.ItemCFRank at 0x15b230470>,
#  915: <__main__.ItemCFRank at 0x15b2304a8>,
#  3852: <__main__.ItemCFRank at 0x15b2304e0>,
#  3618: <__main__.ItemCFRank at 0x15b230518>,
#  3747: <__main__.ItemCFRank at 0x15b230550>,
#  3536: <__main__.ItemCFRank at 0x15b230588>,
#  3794: <__main__.ItemCFRank at 0x15b2305c0>,
#  3861: <__main__.ItemCFRank at 0x15b2305f8>,
#  3916: <__main__.ItemCFRank at 0x15b230630>,
#  3910: <__main__.ItemCFRank at 0x15b230668>,
#  2226: <__main__.ItemCFRank at 0x15b2306a0>,
#  3315: <__main__.ItemCFRank at 0x15b2306d8>,
#  2275: <__main__.ItemCFRank at 0x15b230710>,
#  3796: <__main__.ItemCFRank at 0x15b230748>,
#  2540: <__main__.ItemCFRank at 0x15b230780>,
#  3902: <__main__.ItemCFRank at 0x15b2307b8>,
#  3855: <__main__.ItemCFRank at 0x15b2307f0>,
#  33: <__main__.ItemCFRank at 0x15b230828>,
#  687: <__main__.ItemCFRank at 0x15b230860>,
#  1773: <__main__.ItemCFRank at 0x15b230898>,
#  657: <__main__.ItemCFRank at 0x15b2308d0>,
#  2074: <__main__.ItemCFRank at 0x15b230908>,
#  1924: <__main__.ItemCFRank at 0x15b230940>,
#  1769: <__main__.ItemCFRank at 0x15b230978>,
#  704: <__main__.ItemCFRank at 0x15b2309b0>,
#  1525: <__main__.ItemCFRank at 0x15b2309e8>,
#  958: <__main__.ItemCFRank at 0x15b230a20>,
#  1502: <__main__.ItemCFRank at 0x15b230a58>,
#  2579: <__main__.ItemCFRank at 0x15b230a90>,
#  1355: <__main__.ItemCFRank at 0x15b230ac8>,
#  220: <__main__.ItemCFRank at 0x15b230b00>,
#  2945: <__main__.ItemCFRank at 0x15b230b38>,
#  1151: <__main__.ItemCFRank at 0x15b230b70>,
#  1627: <__main__.ItemCFRank at 0x15b230ba8>,
#  3265: <__main__.ItemCFRank at 0x15b230be0>,
#  714: <__main__.ItemCFRank at 0x15b230c18>,
#  842: <__main__.ItemCFRank at 0x15b230c50>,
#  2899: <__main__.ItemCFRank at 0x15b230c88>,
#  411: <__main__.ItemCFRank at 0x15b230cc0>,
#  2864: <__main__.ItemCFRank at 0x15b230cf8>,
#  3338: <__main__.ItemCFRank at 0x15b230d30>,
#  3704: <__main__.ItemCFRank at 0x15b230d68>,
#  2450: <__main__.ItemCFRank at 0x15b230da0>,
#  2109: <__main__.ItemCFRank at 0x15b230dd8>,
#  1283: <__main__.ItemCFRank at 0x15b230e10>,
#  3167: <__main__.ItemCFRank at 0x15b230e48>,
#  2730: <__main__.ItemCFRank at 0x15b230e80>,
#  1362: <__main__.ItemCFRank at 0x15b230eb8>,
#  1949: <__main__.ItemCFRank at 0x15b230ef0>,
#  1249: <__main__.ItemCFRank at 0x15b230f28>,
#  3783: <__main__.ItemCFRank at 0x15b230f60>,
#  3896: <__main__.ItemCFRank at 0x15b230f98>,
#  3355: <__main__.ItemCFRank at 0x15b230fd0>,
#  3452: <__main__.ItemCFRank at 0x15b23c048>,
#  3409: <__main__.ItemCFRank at 0x15b23c080>,
#  3617: <__main__.ItemCFRank at 0x15b23c0b8>,
#  3274: <__main__.ItemCFRank at 0x15b23c0f0>,
#  3686: <__main__.ItemCFRank at 0x15b23c128>,
#  1586: <__main__.ItemCFRank at 0x15b23c160>,
#  1378: <__main__.ItemCFRank at 0x15b23c198>,
#  1928: <__main__.ItemCFRank at 0x15b23c1d0>,
#  970: <__main__.ItemCFRank at 0x15b23c208>,
#  3368: <__main__.ItemCFRank at 0x15b23c240>,
#  940: <__main__.ItemCFRank at 0x15b23c278>,
#  1931: <__main__.ItemCFRank at 0x15b23c2b0>,
#  3062: <__main__.ItemCFRank at 0x15b23c2e8>,
#  960: <__main__.ItemCFRank at 0x15b23c320>,
#  1934: <__main__.ItemCFRank at 0x15b23c358>,
#  2670: <__main__.ItemCFRank at 0x15b23c390>,
#  1008: <__main__.ItemCFRank at 0x15b23c3c8>,
#  952: <__main__.ItemCFRank at 0x15b23c400>,
#  ...}

# %%
## 计算Recall、Precision、Coverage、Popularity
## 这里定义的流行度是曾经有K个用户进行过行为并取自然对数
## evaluate作用于测试集上

method_list = ['random','most_popular','itemcf']


def evaluate(method = 'itemcf', topN = N, relatedK = K):
    hit = 0
    n_recall = 0
    n_precision = 0
    all_items = len(set(item_list))
    recommended_items = []
    popularity_sum = 0
    
    d = train_set.groupby(['item_id']).size()
    d = sorted(d.items(), key = itemgetter(1), reverse=True)
    
    most_popular_items = set([i[0] for i in d[:topN]])
    
    uniq_item_list = set(item_list)
    
    gini_item_list = {}
    
    for user, items in user_item_test.items():
        if method == 'itemcf':
            rank = recommend(u = user, W = W , topN = topN, relatedK = relatedK)
        elif method == 'most_popular':
            rank = most_popular_items
        elif method == 'random':
            rank = set(random.sample(uniq_item_list, topN))
        else: 
            rank = set()
        hit += len(rank & items)
        n_recall += len(items)
        n_precision += topN
        recommended_items += [i for i in rank]
        popularity_sum += sum([len(item_user[i]) for i in rank])
        
        for i in rank:
            gini_item_list.setdefault(i,0)
            gini_item_list[i] += 1
    
    j = 1
    n = len(gini_item_list)
    G = 0
    gini_item_list = sorted(gini_item_list.items(), key = itemgetter(1), reverse=False)
    g_sum = sum([i[1] for i in gini_item_list])
    
    for i in range(n):
        G += (2 * j - n - 1) * gini_item_list[i][1]
        j += 1
    
    return {'recall': "{0:.2%}".format(hit / (1.0 * n_recall)),
            'precision': "{0:.2%}".format(hit / (1.0 * n_precision)),
            'coverage': "{0:.2%}".format(len(set(recommended_items))/all_items),
            'gini_index': "{0:.2%}".format(G/float(n-1)/g_sum),
            'popularity': "{:.3f}".format(math.log(popularity_sum / n_precision))
           }

# %%
import prettytable
tb = prettytable.PrettyTable()
tb.field_names = ["Method", "Recall", "Precision", "Coverage", "Gini Index", 'Popularity']
for i in method_list:
    l = []
    l.append(i)
    d = evaluate(method = i)
    tb.add_row(l + list(d.values()))
print(tb)
# Out:
# +--------------+--------+-----------+----------+------------+------------+
# |    Method    | Recall | Precision | Coverage | Gini Index | Popularity |
# +--------------+--------+-----------+----------+------------+------------+
# |    random    | 0.28%  |   0.92%   | 100.00%  |   13.82%   |   5.382    |
# | most_popular | 2.77%  |   9.21%   |  0.27%   |   0.00%    |   7.717    |
# |    itemcf    | 8.52%  |   28.27%  |  13.66%  |   85.74%   |   7.389    |
# +--------------+--------+-----------+----------+------------+------------+
